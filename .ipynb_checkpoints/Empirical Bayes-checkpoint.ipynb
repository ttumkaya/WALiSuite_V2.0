# %%
import os
import seaborn as sns
import pandas as pd
from scipy import stats
import scipy as sp
import numpy as np
import datetime as dt
# %matplotlib inline
import matplotlib
# matplotlib.use('Agg')
# %matplotlib notebook
import matplotlib.pyplot as plt
from matplotlib import gridspec
from itertools import groupby
from operator import itemgetter
import dabest
from nptdms import *
import math
from collections import Counter
import shutil
import progressbar
from svgutils.compose import *
from matplotlib.lines import Line2D
import random
import dabest

# %% [markdown]
# ## Prepare Data for EBprot

# %% [markdown]
# ### Calculate Z scores

# %%
Z_scores = {'Di':[], 'Si':[], 'ORNs':[], 'Sex_Satiety_Wind':[], 'LightInt':[]}

rootDirectory = "C:/Users/tumkayat/Desktop/WALISAR_Paper/Figure2/Data/All_merged_intensity_wTSALE/"
ornList = os.listdir(rootDirectory)
bar = progressbar.ProgressBar()

## go thru the ORNs
for ORN in bar(ornList):
    rootDir = os.path.join(rootDirectory, ORN, "weighted_TSALE", "weighted_TSALE_values.pkl")
    
    df = pd.read_pickle(rootDir)
    df = df.assign(Sex_Satiety_Wind = pd.Series(df['Sex'] + '_' + df['Satiety'] + '_' + df['Wind status'], index = df.index))
    
    for condition in df['Sex_Satiety_Wind'].unique():
        for intensity in df['Light Intensity(uW/mm2)'].unique():
            dfOI = df[(df['Sex_Satiety_Wind'] == condition) & (df['Light Intensity(uW/mm2)'] == intensity)] 
            ## calculate the mean difference as Offspring - Parent, since having 2 or 3 independent groups does not affect the mean
            ctrl_wTSALE = dfOI[dfOI['Status'] == 'Parent']['weighted_TSALE_P10']
            exp_wTSALE = dfOI[dfOI['Status'] == 'Offspring']['weighted_TSALE_P10']

            Di = exp_wTSALE.mean() - ctrl_wTSALE.mean()
            
            ## calculate Si for three genotypes and then get the average - different than combining the controls
            genotypes = df['Genotype'].unique()
            
            g0_data = dfOI[dfOI['Genotype'] == genotypes[0]]['weighted_TSALE_P10']
            g1_data = dfOI[dfOI['Genotype'] == genotypes[1]]['weighted_TSALE_P10']
            g2_data = dfOI[dfOI['Genotype'] == genotypes[2]]['weighted_TSALE_P10']
            
            Si = (g0_data.std() + g1_data.std() + g2_data.std()) / 3.
            
            Z_scores['ORNs'].append(ORN)
            Z_scores['Sex_Satiety_Wind'].append(condition)
            Z_scores['LightInt'].append(intensity)
            Z_scores['Di'].append(Di)
            Z_scores['Si'].append(Si)
                     
Z_scores_df = pd.DataFrame(Z_scores)
Z_scores_df_dropna = Z_scores_df.dropna()

a0 = np.percentile(Z_scores_df_dropna['Si'], 90)
Z_scores_df_dropna['Zi'] = Z_scores_df_dropna['Di'] / (a0 + Z_scores_df_dropna['Si'])
# Out:
# 100% |########################################################################|
# C:\Users\tumkayat\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
Z_scores_df_dropna.shape
# Out:
# (711, 6)

# %%
Z_scores_df_dropna['Tag'] = Z_scores_df_dropna['ORNs'] + '_' + Z_scores_df_dropna['Sex_Satiety_Wind']
# Out:
# C:\Users\tumkayat\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
male_fed_noair = Z_scores_df_dropna[Z_scores_df_dropna['Sex_Satiety_Wind'] == 'male_fed_NoAir']
male_fed_noair = male_fed_noair[male_fed_noair['ORNs'] != 'Gr66a']

# %%
male_fed_noair.shape
# Out:
# (151, 7)

# %%
## If you are using only a part of the dataset, i.e. Fed and NoAir, calculate the Z scores for that group only
a0 = np.percentile(male_fed_noair['Si'], 90)
male_fed_noair['Zi'] = male_fed_noair['Di'] / (a0 + male_fed_noair['Si'])

# %%
male_fed_noair.to_csv('C:/Users/tumkayat/Desktop/Fed_and_NoWir_only_woutGr66a.csv')

# %%
##Drop Gr66a, EBprot blows up otherwise
a = Z_scores_df_dropna[Z_scores_df_dropna['ORNs'] != 'Gr66a']
a.shape
# Out:
# (699, 7)

# %%
a.to_csv('C:/Users/tumkayat/Desktop/All_adult_data_woutGr66a_wCombos.csv')

# %% [markdown]
# ### Calculate Z scores using data from DF

# %%
##!!!! Calculate Z scores for stand-alone dataframes
def calculate_Z(a0,Di,Si):
    z_scores = []
    Di = Di.dropna()
    Si = Si.dropna()
    
    for k in range(len(Di)):
        z = Di.iloc[k] / (a0 + Si.iloc[k])
        
        z_scores.append(z)
    return z_scores

# %%
deltadelta_df = pd.read_csv('C:/Users/tumkayat/Desktop/WALISAR_Paper/Figure3/AllDeltaDelta/deltadelta_ES_ALL.csv')

# %%
xyz = pd.read_csv('C:/Users/tumkayat/Desktop/OATAScreennew.csv')

# %%
xyz
# Out:
#               Line   Intensity  Effect_size       SD1       SD2       SD3  \
# 0    GMR76H03-Gal4  1.5-Epoch1    -0.419923  0.355630  0.266922  0.842422
# 1    GMR76H03-Gal4    5-Epoch1    -1.016858  0.329619  0.270036  0.282810
# 2    GMR76H03-Gal4   22-Epoch1    -1.117241  0.248224  0.355752  0.000000
# 3    GMR76H03-Gal4   70-Epoch1    -1.043678  0.307721  0.315637  0.020562
# 4    GMR76H03-Gal4  1.5-Epoch2    -0.298851  0.382404  0.238551  0.867983
# 5    GMR76H03-Gal4    5-Epoch2    -0.894253  0.288062  0.282292  0.402087
# 6    GMR76H03-Gal4   22-Epoch2    -1.066667  0.377282  0.411855  0.000000
# 7    GMR76H03-Gal4   70-Epoch2    -1.004598  0.319427  0.368645  0.136478
# 8    VT058551-Gal4  1.5-Epoch1    -0.763985  0.513478  0.284124  0.253619
# 9    VT058551-Gal4    5-Epoch1    -0.935276  0.337092  0.302748  0.173043
# 10   VT058551-Gal4   22-Epoch1    -1.031756  0.279521  0.349003  0.063103
# 11   VT058551-Gal4   70-Epoch1    -0.455279  0.379339  0.334969  0.859451
# 12   VT058551-Gal4  1.5-Epoch2    -0.894182  0.491634  0.313920  0.348255
# 13   VT058551-Gal4    5-Epoch2    -0.946093  0.347513  0.290553  0.213857
# 14   VT058551-Gal4   22-Epoch2    -0.940034  0.355022  0.388245  0.308150
# 15   VT058551-Gal4   70-Epoch2    -0.375265  0.453764  0.378775  0.894958
# 16     MB113C-Gal4  1.5-Epoch1    -0.259770  0.264045  0.356022  0.419799
# 17     MB113C-Gal4    5-Epoch1    -0.339464  0.320320  0.396674  0.345892
# 18     MB113C-Gal4   22-Epoch1    -0.558621  0.327264  0.418165  0.465311
# 19     MB113C-Gal4   70-Epoch1    -0.340230  0.345141  0.421717  0.661465
# 20     MB113C-Gal4  1.5-Epoch2    -0.236782  0.324011  0.450897  0.478576
# 21     MB113C-Gal4    5-Epoch2    -0.306513  0.394372  0.437057  0.465621
# 22     MB113C-Gal4   22-Epoch2    -0.576245  0.302549  0.463605  0.604864
# 23     MB113C-Gal4   70-Epoch2    -0.494253  0.325904  0.501478  0.612948
# 24   GMR76G11-Gal4  1.5-Epoch1    -0.136242  0.354534  0.354745  0.271712
# 25   GMR76G11-Gal4    5-Epoch1     0.135232  0.232223  0.261428  0.450294
# 26   GMR76G11-Gal4   22-Epoch1    -0.107332  0.283533  0.292252  0.764227
# 27   GMR76G11-Gal4   70-Epoch1    -0.947919  0.257865  0.325276  0.200325
# 28   GMR76G11-Gal4  1.5-Epoch2    -0.096290  0.267192  0.368833  0.328254
# 29   GMR76G11-Gal4    5-Epoch2     0.074347  0.261659  0.250191  0.586926
# ..             ...         ...          ...       ...       ...       ...
# 210  GMR76G04-Gal4   22-Epoch1     0.628759  0.255213  0.362081  0.519278
# 211  GMR76G04-Gal4   70-Epoch1    -0.071012  0.286226  0.347284  0.798247
# 212  GMR76G04-Gal4  1.5-Epoch2    -0.050194  0.340268  0.332223  0.556778
# 213  GMR76G04-Gal4    5-Epoch2     0.217371  0.239992  0.544944  0.720582
# 214  GMR76G04-Gal4   22-Epoch2     0.404385  0.327490  0.466231  0.757251
# 215  GMR76G04-Gal4   70-Epoch2    -0.047276  0.321918  0.359923  0.842072
# 216    Tdc2-Gal4.S  1.5-Epoch1     0.542529  0.439485  0.311500  0.625827
# 217    Tdc2-Gal4.S    5-Epoch1     0.430651  0.393054  0.245421  0.542415
# 218    Tdc2-Gal4.S   22-Epoch1     0.090421  0.264091  0.210727  0.655940
# 219    Tdc2-Gal4.S   70-Epoch1     0.103448  0.279212  0.347202  0.529448
# 220    Tdc2-Gal4.S  1.5-Epoch2     0.075096  0.410985  0.270560  0.848646
# 221    Tdc2-Gal4.S    5-Epoch2     0.260536  0.370925  0.239536  0.687754
# 222    Tdc2-Gal4.S   22-Epoch2     0.354023  0.282827  0.290602  0.601028
# 223    Tdc2-Gal4.S   70-Epoch2     0.262069  0.249767  0.464102  0.588070
# 224      Tdc2-Gal4  1.5-Epoch1     0.525109  0.291197  0.327792  0.555668
# 225      Tdc2-Gal4    5-Epoch1     0.535632  0.387893  0.456140  0.793147
# 226      Tdc2-Gal4   22-Epoch1     0.041379  0.378299  0.266247  0.819926
# 227      Tdc2-Gal4   70-Epoch1     0.390805  0.288936  0.279908  0.805767
# 228      Tdc2-Gal4  1.5-Epoch2     0.374355  0.330471  0.309318  0.719143
# 229      Tdc2-Gal4    5-Epoch2     0.333333  0.401704  0.508457  0.837001
# 230      Tdc2-Gal4   22-Epoch2     0.150958  0.460673  0.337099  0.835493
# 231      Tdc2-Gal4   70-Epoch2     0.180077  0.397810  0.317571  0.854626
# 232  VT058561-Gal4  1.5-Epoch1     0.170115  0.409633  0.248398  0.515439
# 233  VT058561-Gal4    5-Epoch1     0.138697  0.294290  0.215239  0.461559
# 234  VT058561-Gal4   22-Epoch1     0.200766  0.254512  0.268877  0.549071
# 235  VT058561-Gal4   70-Epoch1     0.698084  0.310867  0.277814  0.278833
# 236  VT058561-Gal4  1.5-Epoch2     0.113410  0.455808  0.419060  0.584740
# 237  VT058561-Gal4    5-Epoch2     0.219157  0.361778  0.282062  0.562427
# 238  VT058561-Gal4   22-Epoch2     0.472031  0.362971  0.347831  0.620933
# 239  VT058561-Gal4   70-Epoch2     0.770881  0.312255  0.337206  0.474037
#
#            Si   Zscores
# 0    0.488325 -0.416322
# 1    0.294155 -1.248476
# 2    0.201325 -1.548178
# 3    0.214640 -1.420040
# 4    0.496313 -0.293960
# 5    0.324147 -1.058951
# 6    0.263046 -1.361639
# 7    0.274850 -1.263369
# 8    0.350407 -0.877407
# 9    0.270961 -1.181971
# 10   0.230542 -1.374087
# 11   0.524586 -0.435711
# 12   0.384603 -0.988126
# 13   0.283974 -1.176296
# 14   0.350472 -1.079511
# 15   0.575832 -0.342346
# 16   0.346622 -0.299638
# 17   0.354295 -0.388128
# 18   0.403580 -0.604631
# 19   0.476108 -0.341448
# 20   0.417828 -0.252392
# 21   0.432350 -0.321740
# 22   0.457006 -0.589611
# 23   0.480110 -0.494039
# 24   0.326997 -0.160791
# 25   0.314648  0.161960
# 26   0.446671 -0.110995
# 27   0.261156 -1.212980
# 28   0.321426 -0.114393
# 29   0.366258  0.083858
# ..        ...       ...
# 210  0.378857  0.699257
# 211  0.477252 -0.071185
# 212  0.409757 -0.053967
# 213  0.501840  0.212658
# 214  0.516991  0.389838
# 215  0.507971 -0.045975
# 216  0.458937  0.554019
# 217  0.393630  0.471195
# 218  0.376919  0.100776
# 219  0.385287  0.114230
# 220  0.510064  0.072881
# 221  0.432738  0.273367
# 222  0.391486  0.388264
# 223  0.433980  0.274618
# 224  0.391552  0.575856
# 225  0.545727  0.502445
# 226  0.488157  0.041031
# 227  0.458204  0.399381
# 228  0.452977  0.384624
# 229  0.582387  0.302285
# 230  0.544422  0.141778
# 231  0.523336  0.172544
# 232  0.391156  0.186636
# 233  0.323696  0.164329
# 234  0.357486  0.228712
# 235  0.289171  0.862369
# 236  0.486536  0.112637
# 237  0.402089  0.237591
# 238  0.443912  0.489539
# 239  0.374499  0.861490
#
# [240 rows x 8 columns]

# %%
a0_xyz = np.percentile(xyz['Si'], 90)

# %%
Z_scores_xyz = calculate_Z(a0_xyz, xyz['Effect_size'], xyz['Si'])

# %%
xyz['Zscores'] = Z_scores_xyz

# %%
xyz.to_csv('C:/Users/tumkayat/Desktop/OATA_Screen_Zscores.csv')

# %%
deltadelta_df.columns
# Out:
# Index(['Unnamed: 0', 'ORNs', 'LightInt', 'male_fed_noair_ES',
#        'male_fed_air_ES', 'male_starved_noair_ES', 'male_starved_air_ES',
#        'male_fed_noair_CIs', 'male_fed_air_CIs', 'male_starved_noair_CIs',
#        'male_starved_air_CIs', 'male_fed_noair_parent_n',
#        'male_fed_noair_parent_std', 'male_fed_noair_offspring_n',
#        'male_fed_noair_offspring_std', 'male_fed_air_parent_n',
#        'male_fed_air_parent_std', 'male_fed_air_offspring_n',
#        'male_fed_air_offspring_std', 'male_starved_noair_parent_n',
#        'male_starved_noair_parent_std', 'male_starved_noair_offspring_n',
#        'male_starved_noair_offspring_std', 'male_starved_air_parent_n',
#        'male_starved_air_parent_std', 'male_starved_air_offspring_n',
#        'male_starved_air_offspring_std', 'female_fed_noair_ES',
#        'female_fed_air_ES', 'female_starved_noair_ES', 'female_starved_air_ES',
#        'female_fed_noair_CIs', 'female_fed_air_CIs',
#        'female_starved_noair_CIs', 'female_starved_air_CIs',
#        'female_fed_noair_parent_n', 'female_fed_noair_parent_std',
#        'female_fed_noair_offspring_n', 'female_fed_noair_offspring_std',
#        'female_fed_air_parent_n', 'female_fed_air_parent_std',
#        'female_fed_air_offspring_n', 'female_fed_air_offspring_std',
#        'female_starved_noair_parent_n', 'female_starved_noair_parent_std',
#        'female_starved_noair_offspring_n',
#        'female_starved_noair_offspring_std', 'female_starved_air_parent_n',
#        'female_starved_air_parent_std', 'female_starved_air_offspring_n',
#        'female_starved_air_offspring_std', 'male_fed_air_V_male_fed_noair_ES',
#        'male_starved_air_V_male_starved_noair_ES',
#        'male_fed_noair_V_male_starved_noair_ES',
#        'male_fed_air_V_male_starved_air_ES',
#        'female_fed_noair_V_male_fed_noair_ES',
#        'female_fed_air_V_male_fed_air_ES',
#        'female_starved_noair_V_male_starved_noair_ES',
#        'female_starved_air_V_male_starved_air_ES',
#        'male_fed_air_V_male_fed_noair_CIs',
#        'male_starved_air_V_male_starved_noair_CIs',
#        'male_fed_noair_V_male_starved_noair_CIs',
#        'male_fed_air_V_male_starved_air_CIs',
#        'female_fed_noair_V_male_fed_noair_CIs',
#        'female_starved_noair_V_male_starved_noair_CIs',
#        'female_starved_air_V_male_starved_air_CIs',
#        'female_fed_air_V_male_fed_air_CIs',
#        'male_fed_air_V_male_fed_noair_pooledSD',
#        'male_starved_air_V_male_starved_noair_pooledSD',
#        'male_fed_noair_V_male_starved_noair_pooledSD',
#        'male_fed_air_V_male_starved_air_pooledSD',
#        'female_fed_noair_V_male_fed_noair_pooledSD',
#        'female_starved_noair_V_male_starved_noair_pooledSD',
#        'female_starved_air_V_male_starved_air_pooledSD',
#        'female_fed_air_V_male_fed_air_pooledSD'],
#       dtype='object')

# %%
merge_Si = [
            deltadelta_df['male_fed_air_V_male_fed_noair_pooledSD'].dropna(),
            deltadelta_df['male_starved_air_V_male_starved_noair_pooledSD'].dropna(),
            deltadelta_df['male_fed_noair_V_male_starved_noair_pooledSD'].dropna(),
            deltadelta_df['male_fed_air_V_male_starved_air_pooledSD'].dropna(),
            deltadelta_df['female_fed_noair_V_male_fed_noair_pooledSD'].dropna(),
            deltadelta_df['female_fed_air_V_male_fed_air_pooledSD'].dropna(),
            deltadelta_df['female_starved_noair_V_male_starved_noair_pooledSD'].dropna(),
            deltadelta_df['female_starved_air_V_male_starved_air_pooledSD'].dropna()
           ]

all_model_Si = pd.concat(merge_Si, ignore_index=True)
a0 = np.percentile(all_model_Si, 90)

## Wind
male_fed_air_V_male_fed_noair_ZScores = calculate_Z(a0,deltadelta_df['male_fed_air_V_male_fed_noair_ES'].dropna(), deltadelta_df['male_fed_air_V_male_fed_noair_pooledSD'].dropna())
male_starved_air_V_male_starved_noair_ZScores = calculate_Z(a0,deltadelta_df['male_starved_air_V_male_starved_noair_ES'].dropna(), deltadelta_df['male_starved_air_V_male_starved_noair_pooledSD'].dropna())

## Starvation
male_fed_noair_V_male_starved_noair_ZScores = calculate_Z(a0,deltadelta_df['male_fed_noair_V_male_starved_noair_ES'].dropna(), deltadelta_df['male_fed_noair_V_male_starved_noair_pooledSD'].dropna())
male_fed_air_V_male_starved_air_ZScores = calculate_Z(a0,deltadelta_df['male_fed_air_V_male_starved_air_ES'].dropna(), deltadelta_df['male_fed_air_V_male_starved_air_pooledSD'].dropna())

## Sex
female_fed_noair_V_male_fed_noair_ZScores = calculate_Z(a0,deltadelta_df['female_fed_noair_V_male_fed_noair_ES'].dropna(), deltadelta_df['female_fed_noair_V_male_fed_noair_pooledSD'].dropna())
female_fed_air_V_male_fed_air_ZScores = calculate_Z(a0,deltadelta_df['female_fed_air_V_male_fed_air_ES'].dropna(), deltadelta_df['female_fed_air_V_male_fed_air_pooledSD'].dropna())
female_starved_noair_V_male_starved_noair_ZScores = calculate_Z(a0,deltadelta_df['female_starved_noair_V_male_starved_noair_ES'].dropna(), deltadelta_df['female_starved_noair_V_male_starved_noair_pooledSD'].dropna())
female_starved_air_V_male_starved_air_ZScores = calculate_Z(a0,deltadelta_df['female_starved_air_V_male_starved_air_ES'].dropna(), deltadelta_df['female_starved_air_V_male_starved_air_pooledSD'].dropna())

# %%
## Make DF for male_fed_air_V_male_fed_noair
male_fed_air_V_male_fed_noair_ZScore_dict = {'ORNs':[], 'LightInt':[], 'ZScores':[]}
male_fed_air_V_male_fed_noair_ZScore_DF = pd.DataFrame(male_fed_air_V_male_fed_noair_ZScore_dict)

male_fed_air_V_male_fed_noair_ZScore_DF['ORNs'] = deltadelta_df.dropna(subset=['male_fed_air_V_male_fed_noair_ES'])['ORNs']
male_fed_air_V_male_fed_noair_ZScore_DF['LightInt'] = deltadelta_df.dropna(subset=['male_fed_air_V_male_fed_noair_ES'])['LightInt']
male_fed_air_V_male_fed_noair_ZScore_DF['ZScores'] = male_fed_air_V_male_fed_noair_ZScores
male_fed_air_V_male_fed_noair_ZScore_DF['Condition'] = 'male_fed_air_V_male_fed_noair'

## Make DF for male_starved_air_V_male_starved_noair
male_starved_air_V_male_starved_noair_ZScore_dict = {'ORNs':[], 'LightInt':[], 'ZScores':[]}
male_starved_air_V_male_starved_noair_ZScore_DF = pd.DataFrame(male_starved_air_V_male_starved_noair_ZScore_dict)

male_starved_air_V_male_starved_noair_ZScore_DF['ORNs'] = deltadelta_df.dropna(subset=['male_starved_air_V_male_starved_noair_ES'])['ORNs']
male_starved_air_V_male_starved_noair_ZScore_DF['LightInt'] = deltadelta_df.dropna(subset=['male_starved_air_V_male_starved_noair_ES'])['LightInt']
male_starved_air_V_male_starved_noair_ZScore_DF['ZScores'] = male_starved_air_V_male_starved_noair_ZScores
male_starved_air_V_male_starved_noair_ZScore_DF['Condition'] = 'male_starved_air_V_male_starved_noair'

## Make DF for male_fed_noair_V_male_starved_noair
male_fed_noair_V_male_starved_noair_ZScore_dict = {'ORNs':[], 'LightInt':[], 'ZScores':[]}
male_fed_noair_V_male_starved_noair_ZScore_DF = pd.DataFrame(male_fed_noair_V_male_starved_noair_ZScore_dict)

male_fed_noair_V_male_starved_noair_ZScore_DF['ORNs'] = deltadelta_df.dropna(subset=['male_fed_noair_V_male_starved_noair_ES'])['ORNs']
male_fed_noair_V_male_starved_noair_ZScore_DF['LightInt'] = deltadelta_df.dropna(subset=['male_fed_noair_V_male_starved_noair_ES'])['LightInt']
male_fed_noair_V_male_starved_noair_ZScore_DF['ZScores'] = male_fed_noair_V_male_starved_noair_ZScores
male_fed_noair_V_male_starved_noair_ZScore_DF['Condition'] = 'male_fed_noair_V_male_starved_noair'

## Make DF for male_fed_air_V_male_starved_air
male_fed_air_V_male_starved_air_ZScore_dict = {'ORNs':[], 'LightInt':[], 'ZScores':[]}
male_fed_air_V_male_starved_air_ZScore_DF = pd.DataFrame(male_fed_air_V_male_starved_air_ZScore_dict)

male_fed_air_V_male_starved_air_ZScore_DF['ORNs'] = deltadelta_df.dropna(subset=['male_fed_air_V_male_starved_air_ES'])['ORNs']
male_fed_air_V_male_starved_air_ZScore_DF['LightInt'] = deltadelta_df.dropna(subset=['male_fed_air_V_male_starved_air_ES'])['LightInt']
male_fed_air_V_male_starved_air_ZScore_DF['ZScores'] = male_fed_air_V_male_starved_air_ZScores
male_fed_air_V_male_starved_air_ZScore_DF['Condition'] = 'male_fed_air_V_male_starved_air'

## Make DF for female_fed_noair_V_male_fed_noair
female_fed_noair_V_male_fed_noair_ZScore_dict = {'ORNs':[], 'LightInt':[], 'ZScores':[]}
female_fed_noair_V_male_fed_noair_ZScore_DF = pd.DataFrame(female_fed_noair_V_male_fed_noair_ZScore_dict)

female_fed_noair_V_male_fed_noair_ZScore_DF['ORNs'] = deltadelta_df.dropna(subset=['female_fed_noair_V_male_fed_noair_ES'])['ORNs']
female_fed_noair_V_male_fed_noair_ZScore_DF['LightInt'] = deltadelta_df.dropna(subset=['female_fed_noair_V_male_fed_noair_ES'])['LightInt']
female_fed_noair_V_male_fed_noair_ZScore_DF['ZScores'] = female_fed_noair_V_male_fed_noair_ZScores                                                        
female_fed_noair_V_male_fed_noair_ZScore_DF['Condition'] = 'female_fed_noair_V_male_fed_noair'

## Make DF for female_fed_air_V_male_fed_air
female_fed_air_V_male_fed_air_ZScore_dict = {'ORNs':[], 'LightInt':[], 'ZScores':[]}
female_fed_air_V_male_fed_air_ZScore_DF = pd.DataFrame(female_fed_air_V_male_fed_air_ZScore_dict)

female_fed_air_V_male_fed_air_ZScore_DF['ORNs'] = deltadelta_df.dropna(subset=['female_fed_air_V_male_fed_air_ES'])['ORNs']
female_fed_air_V_male_fed_air_ZScore_DF['LightInt'] = deltadelta_df.dropna(subset=['female_fed_air_V_male_fed_air_ES'])['LightInt']
female_fed_air_V_male_fed_air_ZScore_DF['ZScores'] = female_fed_air_V_male_fed_air_ZScores
female_fed_air_V_male_fed_air_ZScore_DF['Condition'] = 'female_fed_air_V_male_fed_air'

## Make DF for female_starved_noair_V_male_starved_noair
female_starved_noair_V_male_starved_noair_ZScore_dict = {'ORNs':[], 'LightInt':[], 'ZScores':[]}
female_starved_noair_V_male_starved_noair_ZScore_DF = pd.DataFrame(female_starved_noair_V_male_starved_noair_ZScore_dict)

female_starved_noair_V_male_starved_noair_ZScore_DF['ORNs'] = deltadelta_df.dropna(subset=['female_starved_noair_V_male_starved_noair_ES'])['ORNs']
female_starved_noair_V_male_starved_noair_ZScore_DF['LightInt'] = deltadelta_df.dropna(subset=['female_starved_noair_V_male_starved_noair_ES'])['LightInt']
female_starved_noair_V_male_starved_noair_ZScore_DF['ZScores'] = female_starved_noair_V_male_starved_noair_ZScores
female_starved_noair_V_male_starved_noair_ZScore_DF['Condition'] = 'female_starved_noair_V_male_starved_noair'

## Make DF for female_starved_air_V_male_starved_air
female_starved_air_V_male_starved_air_ZScore_dict = {'ORNs':[], 'LightInt':[], 'ZScores':[]}
female_starved_air_V_male_starved_air_ZScore_DF = pd.DataFrame(female_starved_air_V_male_starved_air_ZScore_dict)

female_starved_air_V_male_starved_air_ZScore_DF['ORNs'] = deltadelta_df.dropna(subset=['female_starved_air_V_male_starved_air_ES'])['ORNs']
female_starved_air_V_male_starved_air_ZScore_DF['LightInt'] = deltadelta_df.dropna(subset=['female_starved_air_V_male_starved_air_ES'])['LightInt']
female_starved_air_V_male_starved_air_ZScore_DF['ZScores'] = female_starved_air_V_male_starved_air_ZScores
female_starved_air_V_male_starved_air_ZScore_DF['Condition'] = 'female_starved_air_V_male_starved_air'

# %%
merge = [male_fed_air_V_male_fed_noair_ZScore_DF, male_starved_air_V_male_starved_noair_ZScore_DF,
         male_fed_noair_V_male_starved_noair_ZScore_DF, male_fed_air_V_male_starved_air_ZScore_DF,
         female_fed_noair_V_male_fed_noair_ZScore_DF, female_fed_air_V_male_fed_air_ZScore_DF,
         female_starved_noair_V_male_starved_noair_ZScore_DF, female_starved_air_V_male_starved_air_ZScore_DF]

deltadelta_ZScore_Table = pd.concat(merge, ignore_index=True)

# %%
airEffect = deltadelta_ZScore_Table[(deltadelta_ZScore_Table['Condition'] == 'male_fed_air_V_male_fed_noair') | (deltadelta_ZScore_Table['Condition'] == 'male_starved_air_V_male_starved_noair') ]
airEffect['ORNs'] = airEffect['ORNs'] + '_' + airEffect['Condition']
airEffect.to_csv("C:/Users/tumkayat/Desktop/deltadelta_ZScores_Air_Effect_Only.csv")
# Out:
# C:\Users\tumkayat\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
starvationEffect = deltadelta_ZScore_Table[(deltadelta_ZScore_Table['Condition'] == 'male_fed_air_V_male_starved_air') | (deltadelta_ZScore_Table['Condition'] == 'male_fed_noair_V_male_starved_noair') ]
starvationEffect['ORNs'] = starvationEffect['ORNs'] + '_' + starvationEffect['Condition']
starvationEffect.to_csv("C:/Users/tumkayat/Desktop/deltadelta_ZScores_Starvation_Effect_Only.csv")
# Out:
# C:\Users\tumkayat\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
sexEffect = deltadelta_ZScore_Table[(deltadelta_ZScore_Table['Condition'] == 'female_fed_air_V_male_fed_air') | (deltadelta_ZScore_Table['Condition'] == 'female_fed_noair_V_male_fed_noair') | \
                                   (deltadelta_ZScore_Table['Condition'] == 'female_starved_noair_V_male_starved_air') | (deltadelta_ZScore_Table['Condition'] == 'female_starved_noair_V_male_starved_noair')]
sexEffect['ORNs'] = sexEffect['ORNs'] + '_' + sexEffect['Condition']
sexEffect.to_csv("C:/Users/tumkayat/Desktop/deltadelta_ZScores_Sex_Effect_Only.csv")
# Out:
# C:\Users\tumkayat\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
deltadelta_ZScore_Table['ORNs'] = deltadelta_ZScore_Table['ORNs'] + '_' + deltadelta_ZScore_Table['Condition']
deltadelta_ZScore_Table.to_csv("C:/Users/tumkayat/Desktop/deltadelta_ZScores_ALL.csv")

# %%
deltadelta_ZScore_Table
# Out:
#       ORNs LightInt   ZScores                                  Condition
# 0    Gr21a     14uW -0.043150              male_fed_air_V_male_fed_noair
# 1    Gr21a     42uW  0.114176              male_fed_air_V_male_fed_noair
# 2    Gr21a     70uW -0.062242              male_fed_air_V_male_fed_noair
# 3    Gr63a     14uW -0.020030              male_fed_air_V_male_fed_noair
# 4    Gr63a     42uW -0.188615              male_fed_air_V_male_fed_noair
# 5    Gr63a     70uW -0.240906              male_fed_air_V_male_fed_noair
# 6    Gr66a     14uW -0.321114              male_fed_air_V_male_fed_noair
# 7    Gr66a     42uW -0.153370              male_fed_air_V_male_fed_noair
# 8    Gr66a     70uW  0.056530              male_fed_air_V_male_fed_noair
# 9    Or10a     14uW  0.169194              male_fed_air_V_male_fed_noair
# 10   Or10a     42uW  0.053844              male_fed_air_V_male_fed_noair
# 11   Or10a     70uW -0.137054              male_fed_air_V_male_fed_noair
# 12   Or13a     14uW -0.153341              male_fed_air_V_male_fed_noair
# 13   Or13a     42uW  0.003125              male_fed_air_V_male_fed_noair
# 14   Or13a     70uW  0.073583              male_fed_air_V_male_fed_noair
# 15   Or19a     14uW -0.147768              male_fed_air_V_male_fed_noair
# 16   Or19a     42uW -0.068225              male_fed_air_V_male_fed_noair
# 17   Or19a     70uW -0.158304              male_fed_air_V_male_fed_noair
# 18   Or19b     14uW  0.082657              male_fed_air_V_male_fed_noair
# 19   Or19b     42uW -0.046339              male_fed_air_V_male_fed_noair
# 20   Or19b     70uW -0.026659              male_fed_air_V_male_fed_noair
# 21   Or22a     14uW -0.130901              male_fed_air_V_male_fed_noair
# 22   Or22a     42uW  0.086685              male_fed_air_V_male_fed_noair
# 23   Or22a     70uW -0.068188              male_fed_air_V_male_fed_noair
# 24   Or22b     14uW -0.042054              male_fed_air_V_male_fed_noair
# 25   Or22b     42uW -0.084573              male_fed_air_V_male_fed_noair
# 26   Or22b     70uW  0.096751              male_fed_air_V_male_fed_noair
# 27   Or23a     14uW  0.213203              male_fed_air_V_male_fed_noair
# 28   Or23a     42uW  0.026357              male_fed_air_V_male_fed_noair
# 29   Or23a     70uW -0.231349              male_fed_air_V_male_fed_noair
# ..     ...      ...       ...                                        ...
# 602  Or47b     14uW  0.209511  female_starved_noair_V_male_starved_noair
# 603  Or47b     42uW -0.221288  female_starved_noair_V_male_starved_noair
# 604  Or47b     70uW  0.005464  female_starved_noair_V_male_starved_noair
# 605  Or65a     14uW  0.149995  female_starved_noair_V_male_starved_noair
# 606  Or65a     42uW  0.001573  female_starved_noair_V_male_starved_noair
# 607  Or65a     70uW -0.136810  female_starved_noair_V_male_starved_noair
# 608  Or67d     14uW  0.027615  female_starved_noair_V_male_starved_noair
# 609  Or67d     42uW -0.021800  female_starved_noair_V_male_starved_noair
# 610  Or67d     70uW -0.012512  female_starved_noair_V_male_starved_noair
# 611  Or88a     14uW -0.233662  female_starved_noair_V_male_starved_noair
# 612  Or88a     42uW  0.061114  female_starved_noair_V_male_starved_noair
# 613  Or88a     70uW  0.027305  female_starved_noair_V_male_starved_noair
# 614   Orco     14uW  0.013859  female_starved_noair_V_male_starved_noair
# 615   Orco     42uW  0.069580  female_starved_noair_V_male_starved_noair
# 616   Orco     70uW  0.173720  female_starved_noair_V_male_starved_noair
# 617  Or47b     14uW -0.179380      female_starved_air_V_male_starved_air
# 618  Or47b     42uW -0.061636      female_starved_air_V_male_starved_air
# 619  Or47b     70uW -0.132953      female_starved_air_V_male_starved_air
# 620  Or65a     14uW -0.113303      female_starved_air_V_male_starved_air
# 621  Or65a     42uW  0.148036      female_starved_air_V_male_starved_air
# 622  Or65a     70uW -0.139027      female_starved_air_V_male_starved_air
# 623  Or67d     14uW -0.056032      female_starved_air_V_male_starved_air
# 624  Or67d     42uW  0.154891      female_starved_air_V_male_starved_air
# 625  Or67d     70uW  0.067864      female_starved_air_V_male_starved_air
# 626  Or88a     14uW -0.156847      female_starved_air_V_male_starved_air
# 627  Or88a     42uW -0.102155      female_starved_air_V_male_starved_air
# 628  Or88a     70uW  0.008579      female_starved_air_V_male_starved_air
# 629   Orco     14uW -0.309811      female_starved_air_V_male_starved_air
# 630   Orco     42uW -0.194256      female_starved_air_V_male_starved_air
# 631   Orco     70uW -0.147031      female_starved_air_V_male_starved_air
#
# [632 rows x 4 columns]

# %%
a
# Out:
#            Di        Si   ORNs      Sex_Satiety_Wind LightInt        Zi  \
# 0    0.090131  0.427006  Gr21a        male_fed_NoAir     14uW  0.090775
# 1   -0.243048  0.346521  Gr21a        male_fed_NoAir     42uW -0.266378
# 2   -0.134207  0.345914  Gr21a        male_fed_NoAir     70uW -0.147186
# 3    0.044154  0.523822  Gr21a          male_fed_Air     14uW  0.040519
# 4   -0.131724  0.428363  Gr21a          male_fed_Air     42uW -0.132484
# 5   -0.197315  0.499151  Gr21a          male_fed_Air     70uW -0.185264
# 6    0.078018  0.432651  Gr21a    male_starved_NoAir     14uW  0.078131
# 7   -0.189169  0.292172  Gr21a    male_starved_NoAir     42uW -0.220459
# 8   -0.192463  0.283009  Gr21a    male_starved_NoAir     70uW -0.226718
# 9   -0.037381  0.464686  Gr21a      male_starved_Air     14uW -0.036272
# 10  -0.103921  0.381695  Gr21a      male_starved_Air     42uW -0.109668
# 11  -0.177794  0.349230  Gr21a      male_starved_Air     70uW -0.194284
# 12  -0.018967  0.473301  Gr63a    male_starved_NoAir     14uW -0.018251
# 13   0.105618  0.417341  Gr63a    male_starved_NoAir     42uW  0.107418
# 14   0.007042  0.437511  Gr63a    male_starved_NoAir     70uW  0.007018
# 15  -0.408698  0.553870  Gr63a      male_starved_Air     14uW -0.364984
# 16  -0.246635  0.484545  Gr63a      male_starved_Air     42uW -0.234791
# 17  -0.250337  0.494305  Gr63a      male_starved_Air     70uW -0.236122
# 18  -0.025401  0.463212  Gr63a        male_fed_NoAir     14uW -0.024682
# 19  -0.066340  0.413382  Gr63a        male_fed_NoAir     42uW -0.067744
# 20  -0.008951  0.415281  Gr63a        male_fed_NoAir     70uW -0.009123
# 21  -0.049420  0.551528  Gr63a          male_fed_Air     14uW -0.044226
# 22  -0.287506  0.496788  Gr63a          male_fed_Air     42uW -0.270547
# 23  -0.288192  0.427501  Gr63a          male_fed_Air     70uW -0.290107
# 36  -0.104535  0.394700  Or10a    male_starved_NoAir     14uW -0.108823
# 37   0.081807  0.397783  Or10a    male_starved_NoAir     42uW  0.084890
# 38   0.102450  0.333677  Or10a    male_starved_NoAir     70uW  0.113886
# 39   0.169547  0.522994  Or10a      male_starved_Air     14uW  0.155706
# 40   0.200243  0.477152  Or10a      male_starved_Air     42uW  0.191979
# 41   0.297882  0.462722  Or10a      male_starved_Air     70uW  0.289593
# ..        ...       ...    ...                   ...      ...       ...
# 714  0.074070  0.455355   Or9a        male_fed_NoAir     14uW  0.072528
# 715  0.035658  0.500072   Or9a        male_fed_NoAir     42uW  0.033451
# 716  0.165264  0.414477   Or9a        male_fed_NoAir     70uW  0.168572
# 717  0.146441  0.603795   Or9a          male_fed_Air     14uW  0.125196
# 718 -0.007014  0.545002   Or9a          male_fed_Air     42uW -0.006314
# 719  0.154510  0.559774   Or9a          male_fed_Air     70uW  0.137260
# 720  0.048294  0.509191   Orco    male_starved_NoAir     14uW  0.044921
# 721  0.135630  0.491487   Orco    male_starved_NoAir     42uW  0.128270
# 722  0.182030  0.430401   Orco    male_starved_NoAir     70uW  0.182706
# 723  0.255465  0.604491   Orco      male_starved_Air     14uW  0.218274
# 724  0.426554  0.552758   Orco      male_starved_Air     42uW  0.381309
# 725  0.401259  0.488485   Orco      male_starved_Air     70uW  0.380563
# 726  0.052353  0.538653   Orco        male_fed_NoAir     14uW  0.047397
# 727  0.289947  0.521173   Orco        male_fed_NoAir     42uW  0.266723
# 728  0.272716  0.513120   Orco        male_fed_NoAir     70uW  0.252745
# 729  0.147811  0.612954   Orco          male_fed_Air     14uW  0.125386
# 730  0.463668  0.578495   Orco          male_fed_Air     42uW  0.405165
# 731  0.472507  0.506720   Orco          male_fed_Air     70uW  0.440517
# 732 -0.113971  0.487912   Orco      female_fed_NoAir     14uW -0.108152
# 733 -0.050173  0.556962   Orco      female_fed_NoAir     42uW -0.044684
# 734 -0.039523  0.473385   Orco      female_fed_NoAir     70uW -0.038029
# 735  0.000403  0.578358   Orco        female_fed_Air     14uW  0.000352
# 736 -0.096886  0.557936   Orco        female_fed_Air     42uW -0.086210
# 737  0.132802  0.522702   Orco        female_fed_Air     70uW  0.121993
# 738  0.064503  0.483199   Orco  female_starved_NoAir     14uW  0.061484
# 739  0.213645  0.428637   Orco  female_starved_NoAir     42uW  0.214819
# 740  0.360068  0.354644   Orco  female_starved_NoAir     70uW  0.391147
# 741 -0.122330  0.480809   Orco    female_starved_Air     14uW -0.116871
# 742  0.200951  0.514582   Orco    female_starved_Air     42uW  0.185983
# 743  0.246195  0.470411   Orco    female_starved_Air     70uW  0.237569
#
#                            Tag
# 0         Gr21a_male_fed_NoAir
# 1         Gr21a_male_fed_NoAir
# 2         Gr21a_male_fed_NoAir
# 3           Gr21a_male_fed_Air
# 4           Gr21a_male_fed_Air
# 5           Gr21a_male_fed_Air
# 6     Gr21a_male_starved_NoAir
# 7     Gr21a_male_starved_NoAir
# 8     Gr21a_male_starved_NoAir
# 9       Gr21a_male_starved_Air
# 10      Gr21a_male_starved_Air
# 11      Gr21a_male_starved_Air
# 12    Gr63a_male_starved_NoAir
# 13    Gr63a_male_starved_NoAir
# 14    Gr63a_male_starved_NoAir
# 15      Gr63a_male_starved_Air
# 16      Gr63a_male_starved_Air
# 17      Gr63a_male_starved_Air
# 18        Gr63a_male_fed_NoAir
# 19        Gr63a_male_fed_NoAir
# 20        Gr63a_male_fed_NoAir
# 21          Gr63a_male_fed_Air
# 22          Gr63a_male_fed_Air
# 23          Gr63a_male_fed_Air
# 36    Or10a_male_starved_NoAir
# 37    Or10a_male_starved_NoAir
# 38    Or10a_male_starved_NoAir
# 39      Or10a_male_starved_Air
# 40      Or10a_male_starved_Air
# 41      Or10a_male_starved_Air
# ..                         ...
# 714        Or9a_male_fed_NoAir
# 715        Or9a_male_fed_NoAir
# 716        Or9a_male_fed_NoAir
# 717          Or9a_male_fed_Air
# 718          Or9a_male_fed_Air
# 719          Or9a_male_fed_Air
# 720    Orco_male_starved_NoAir
# 721    Orco_male_starved_NoAir
# 722    Orco_male_starved_NoAir
# 723      Orco_male_starved_Air
# 724      Orco_male_starved_Air
# 725      Orco_male_starved_Air
# 726        Orco_male_fed_NoAir
# 727        Orco_male_fed_NoAir
# 728        Orco_male_fed_NoAir
# 729          Orco_male_fed_Air
# 730          Orco_male_fed_Air
# 731          Orco_male_fed_Air
# 732      Orco_female_fed_NoAir
# 733      Orco_female_fed_NoAir
# 734      Orco_female_fed_NoAir
# 735        Orco_female_fed_Air
# 736        Orco_female_fed_Air
# 737        Orco_female_fed_Air
# 738  Orco_female_starved_NoAir
# 739  Orco_female_starved_NoAir
# 740  Orco_female_starved_NoAir
# 741    Orco_female_starved_Air
# 742    Orco_female_starved_Air
# 743    Orco_female_starved_Air
#
# [699 rows x 7 columns]

# %% [markdown]
# ## Prepare EBprot RESULTS

# %%
allData_meanFixed_df = pd.read_csv("C:/Users/tumkayat/Desktop/allData_Z_Gr66aREMOVED_CombosADDED_RESULTS.csv")

# %%
allData_meanFixed_df['Condition'] = allData_meanFixed_df['ZI.Protein'].apply(lambda x: x.split('_')[1:])
allData_meanFixed_df['ORNs'] = allData_meanFixed_df['ZI.Protein'].apply(lambda x: x.split('_')[0])
allData_meanFixed_df['Condition'] = allData_meanFixed_df['Condition'].apply(lambda x: x[0] + '_' + x[1] + '_' + x[2])

# %%
listOfHits = allData_meanFixed_df[(allData_meanFixed_df["ZI.BFDR"] <= 0.2)].sort_values('Condition')  #& (allData_meanFixed_df["Condition"] == 'male_fed_Air')]
listOfHits
# Out:
#      Unnamed: 0                 ZI.Protein  ZI.MedianRatio  ZI.PepNum  \
# 173         174       Or67d_female_fed_Air           0.319          3
# 172         173     Or67d_female_fed_NoAir           0.263          3
# 179         180   Or67d_female_starved_Air           0.223          3
# 262         263  Orco_female_starved_NoAir           0.285          3
# 7             8         Gr63a_male_fed_Air          -0.352          3
# 259         260          Orco_male_fed_Air           0.516          3
# 117         118         Or49a_male_fed_Air           0.316          1
# 77           78         Or42b_male_fed_Air           0.154          5
# 133         134         Or59b_male_fed_Air          -0.212          3
# 69           70         Or35a_male_fed_Air           0.353          3
# 63           64   Or33b-Or85a_male_fed_Air          -0.255          3
# 57           58         Or33b_male_fed_Air          -0.256          3
# 105         106         Or47a_male_fed_Air           0.301          5
# 137         138         Or59c_male_fed_Air          -0.210          5
# 185         186         Or71a_male_fed_Air          -0.207          3
# 205         206         Or83c_male_fed_Air           0.356          3
# 11           12         Or10a_male_fed_Air           0.306          3
# 222         223         Or85d_male_fed_Air          -0.216          3
# 174         175       Or67d_male_fed_NoAir           0.267          5
# 223         224       Or85d_male_fed_NoAir          -0.245          3
# 244         245       Or94b_male_fed_NoAir          -0.116          3
# 136         137       Or59c_male_fed_NoAir          -0.105          5
# 204         205       Or83c_male_fed_NoAir           0.173          3
# 130         131       Or59a_male_fed_NoAir           0.202          3
# 126         127       Or56a_male_fed_NoAir          -0.158          3
# 258         259        Orco_male_fed_NoAir           0.327          3
# 104         105       Or47a_male_fed_NoAir           0.262          5
# 0             1       Gr21a_male_fed_NoAir          -0.201          3
# 112         113       Or47b_male_fed_NoAir           0.156          3
# 92           93       Or45a_male_fed_NoAir           0.190          3
# ..          ...                        ...             ...        ...
# 76           77       Or42b_male_fed_NoAir           0.237          5
# 36           37       Or22c_male_fed_NoAir          -0.207          3
# 68           69       Or35a_male_fed_NoAir           0.240          3
# 21           22     Or19b_male_starved_Air          -0.200          3
# 5             6     Gr63a_male_starved_Air          -0.307          3
# 95           96     Or45a_male_starved_Air           0.384          3
# 3             4     Gr21a_male_starved_Air          -0.148          3
# 45           46     Or24a_male_starved_Air          -0.220          3
# 247         248     Or94b_male_starved_Air           0.207          3
# 251         252     Or98a_male_starved_Air          -0.257          3
# 9            10     Or10a_male_starved_Air           0.251          3
# 139         140     Or59c_male_starved_Air          -0.295          3
# 257         258      Orco_male_starved_Air           0.489          3
# 59           60     Or33b_male_starved_Air          -0.256          3
# 71           72     Or35a_male_starved_Air           0.244          3
# 109         110     Or47b_male_starved_Air           0.229          3
# 169         170     Or67c_male_starved_Air          -0.148          3
# 221         222     Or85d_male_starved_Air          -0.297          3
# 230         231   Or85f_male_starved_NoAir          -0.229          3
# 2             3   Gr21a_male_starved_NoAir          -0.309          3
# 94           95   Or45a_male_starved_NoAir           0.415          3
# 202         203   Or83a_male_starved_NoAir          -0.173          3
# 38           39   Or22c_male_starved_NoAir          -0.152          3
# 44           45   Or24a_male_starved_NoAir          -0.291          3
# 52           53   Or33a_male_starved_NoAir          -0.194          3
# 166         167   Or67b_male_starved_NoAir           0.258          3
# 138         139   Or59c_male_starved_NoAir          -0.088          3
# 70           71   Or35a_male_starved_NoAir           0.201          3
# 18           19   Or19a_male_starved_NoAir           0.225          3
# 176         177   Or67d_male_starved_NoAir           0.167          5
#
#      ZI.PepNumRemoved  ZI.Probability  ZI.FLAG  ZI.PosteriorOdds  ZI.BFDR  \
# 173                 0           0.930      NaN             2.582    0.014
# 172                 0           0.737      NaN             1.032    0.070
# 179                 0           0.754      NaN             1.123    0.065
# 262                 0           0.998      NaN             6.210    0.000
# 7                   0          -0.992      NaN             4.804    0.002
# 259                 0           1.000      NaN            13.557    0.000
# 117                 0           0.651      NaN             0.623    0.101
# 77                  0           1.000      NaN            10.400    0.000
# 133                 0          -1.000      NaN            10.866    0.000
# 69                  0           1.000      NaN             8.523    0.000
# 63                  0          -0.979      NaN             3.854    0.003
# 57                  0          -0.997      NaN             5.907    0.001
# 105                 0           1.000      NaN            14.943    0.000
# 137                 0          -1.000      NaN             8.099    0.000
# 185                 0          -0.781      NaN             1.270    0.046
# 205                 0           0.998      NaN             6.263    0.000
# 11                  0           0.391      NaN            -0.442    0.180
# 222                 0          -0.792      NaN             1.336    0.041
# 174                 0           1.000      NaN            11.280    0.000
# 223                 0          -0.778      NaN             1.254    0.051
# 244                 0          -0.639      NaN             0.571    0.111
# 136                 0          -0.551      NaN             0.205    0.123
# 204                 0           0.407      NaN            -0.377    0.165
# 130                 0           0.375      NaN            -0.510    0.187
# 126                 0          -0.652      NaN             0.626    0.096
# 258                 0           0.901      NaN             2.207    0.021
# 104                 0           0.998      NaN             6.188    0.001
# 0                   0          -0.534      NaN             0.137    0.142
# 112                 0           0.683      NaN             0.766    0.085
# 92                  0           0.402      NaN            -0.397    0.172
# ..                ...             ...      ...               ...      ...
# 76                  0           1.000      NaN            10.572    0.000
# 36                  0          -0.681      NaN             0.758    0.090
# 68                  0           0.826      NaN             1.555    0.036
# 21                  0          -0.536      NaN             0.145    0.130
# 5                   0          -1.000      NaN             8.979    0.000
# 95                  0           0.994      NaN             5.131    0.001
# 3                   0          -0.426      NaN            -0.298    0.157
# 45                  0          -0.861      NaN             1.825    0.028
# 247                 0           0.918      NaN             2.420    0.018
# 251                 0          -0.999      NaN             6.822    0.000
# 9                   0           0.976      NaN             3.725    0.004
# 139                 0          -0.994      NaN             5.113    0.001
# 257                 0           1.000      NaN            12.657    0.000
# 59                  0          -0.953      NaN             3.010    0.007
# 71                  0           0.940      NaN             2.745    0.009
# 109                 0           0.454      NaN            -0.186    0.150
# 169                 0          -0.644      NaN             0.591    0.106
# 221                 0          -0.966      NaN             3.357    0.005
# 230                 0          -0.929      NaN             2.569    0.016
# 2                   0          -0.726      NaN             0.973    0.075
# 94                  0           1.000      NaN            10.161    0.000
# 202                 0          -0.768      NaN             1.198    0.060
# 38                  0          -0.930      NaN             2.590    0.011
# 44                  0          -0.990      NaN             4.555    0.002
# 52                  0          -0.535      NaN             0.141    0.136
# 166                 0           0.774      NaN             1.233    0.056
# 138                 0          -0.374      NaN            -0.514    0.194
# 70                  0           0.719      NaN             0.940    0.079
# 18                  0           0.864      NaN             1.847    0.024
# 176                 0           0.624      NaN             0.506    0.117
#
#                 Condition         ORNs
# 173        female_fed_Air        Or67d
# 172      female_fed_NoAir        Or67d
# 179    female_starved_Air        Or67d
# 262  female_starved_NoAir         Orco
# 7            male_fed_Air        Gr63a
# 259          male_fed_Air         Orco
# 117          male_fed_Air        Or49a
# 77           male_fed_Air        Or42b
# 133          male_fed_Air        Or59b
# 69           male_fed_Air        Or35a
# 63           male_fed_Air  Or33b-Or85a
# 57           male_fed_Air        Or33b
# 105          male_fed_Air        Or47a
# 137          male_fed_Air        Or59c
# 185          male_fed_Air        Or71a
# 205          male_fed_Air        Or83c
# 11           male_fed_Air        Or10a
# 222          male_fed_Air        Or85d
# 174        male_fed_NoAir        Or67d
# 223        male_fed_NoAir        Or85d
# 244        male_fed_NoAir        Or94b
# 136        male_fed_NoAir        Or59c
# 204        male_fed_NoAir        Or83c
# 130        male_fed_NoAir        Or59a
# 126        male_fed_NoAir        Or56a
# 258        male_fed_NoAir         Orco
# 104        male_fed_NoAir        Or47a
# 0          male_fed_NoAir        Gr21a
# 112        male_fed_NoAir        Or47b
# 92         male_fed_NoAir        Or45a
# ..                    ...          ...
# 76         male_fed_NoAir        Or42b
# 36         male_fed_NoAir        Or22c
# 68         male_fed_NoAir        Or35a
# 21       male_starved_Air        Or19b
# 5        male_starved_Air        Gr63a
# 95       male_starved_Air        Or45a
# 3        male_starved_Air        Gr21a
# 45       male_starved_Air        Or24a
# 247      male_starved_Air        Or94b
# 251      male_starved_Air        Or98a
# 9        male_starved_Air        Or10a
# 139      male_starved_Air        Or59c
# 257      male_starved_Air         Orco
# 59       male_starved_Air        Or33b
# 71       male_starved_Air        Or35a
# 109      male_starved_Air        Or47b
# 169      male_starved_Air        Or67c
# 221      male_starved_Air        Or85d
# 230    male_starved_NoAir        Or85f
# 2      male_starved_NoAir        Gr21a
# 94     male_starved_NoAir        Or45a
# 202    male_starved_NoAir        Or83a
# 38     male_starved_NoAir        Or22c
# 44     male_starved_NoAir        Or24a
# 52     male_starved_NoAir        Or33a
# 166    male_starved_NoAir        Or67b
# 138    male_starved_NoAir        Or59c
# 70     male_starved_NoAir        Or35a
# 18     male_starved_NoAir        Or19a
# 176    male_starved_NoAir        Or67d
#
# [61 rows x 11 columns]

# %%
allData_meanFixed_df['Condition'].unique()
# Out:
# array(['male_fed_NoAir', 'male_fed_Air', 'male_starved_NoAir',
#        'male_starved_Air', 'female_fed_NoAir', 'female_fed_Air',
#        'female_starved_NoAir', 'female_starved_Air'], dtype=object)

# %%
listOfHits.to_csv("C:/Users/tumkayat/Desktop/AllData_Combos_NoGr66a_BFDR_0.2_results.csv")

# %%
allData_meanFixedFALSE_df = pd.read_csv("C:/Users/tumkayat/Desktop/allData_Gr66aREMOVED_CombosADDED_RESULTS.csv")

# %%
allData_meanFixedFALSE_df['Condition'] = allData_meanFixedFALSE_df['ZI.Protein'].apply(lambda x: x.split('_')[1:])
allData_meanFixedFALSE_df['ORNs'] = allData_meanFixedFALSE_df['ZI.Protein'].apply(lambda x: x.split('_')[0])
allData_meanFixedFALSE_df['Condition'] = allData_meanFixedFALSE_df['Condition'].apply(lambda x: x[0] + '_' + x[1] + '_' + x[2])

# %%
allData_meanFixedFALSE_df[(allData_meanFixedFALSE_df["ZI.BFDR"] <= 0.3) & (allData_meanFixedFALSE_df["Condition"] == 'male_fed_Air')]
# Out:
#      Unnamed: 0                ZI.Protein  ZI.MedianRatio  ZI.PepNum  \
# 1             2        Gr21a_male_fed_Air          -0.176          3
# 7             8        Gr63a_male_fed_Air          -0.352          3
# 11           12        Or10a_male_fed_Air           0.306          3
# 25           26         Or1a_male_fed_Air           0.184          3
# 59           60        Or33b_male_fed_Air          -0.256          3
# 65           66  Or33b-Or85a_male_fed_Air          -0.255          3
# 71           72        Or35a_male_fed_Air           0.354          3
# 79           80        Or42b_male_fed_Air           0.154          5
# 107         108        Or47a_male_fed_Air           0.302          5
# 119         120        Or49a_male_fed_Air           0.316          1
# 135         136        Or59b_male_fed_Air          -0.212          3
# 139         140        Or59c_male_fed_Air          -0.210          5
# 173         174        Or67c_male_fed_Air          -0.095          3
# 187         188        Or71a_male_fed_Air          -0.207          3
# 207         208        Or83c_male_fed_Air           0.357          3
# 226         227        Or85d_male_fed_Air          -0.216          3
# 243         244        Or88a_male_fed_Air          -0.059          3
# 263         264         Orco_male_fed_Air           0.516          3
#
#      ZI.PepNumRemoved  ZI.Probability  ZI.FLAG  ZI.PosteriorOdds  ZI.BFDR  \
# 1                   0          -0.196      NaN            -1.409    0.258
# 7                   0          -0.992      NaN             4.876    0.002
# 11                  0           0.415      NaN            -0.342    0.170
# 25                  0           0.303      NaN            -0.835    0.193
# 59                  0          -0.997      NaN             5.987    0.001
# 65                  0          -0.980      NaN             3.917    0.003
# 71                  0           1.000      NaN             8.642    0.000
# 79                  0           1.000      NaN            10.620    0.000
# 107                 0           1.000      NaN            15.133    0.000
# 119                 0           0.661      NaN             0.668    0.095
# 135                 0          -1.000      NaN            10.982    0.000
# 139                 0          -1.000      NaN             8.191    0.000
# 173                 0          -0.236      NaN            -1.172    0.218
# 187                 0          -0.789      NaN             1.318    0.049
# 207                 0           0.998      NaN             6.376    0.000
# 226                 0          -0.800      NaN             1.387    0.040
# 243                 0          -0.162      NaN            -1.646    0.288
# 263                 0           1.000      NaN            13.722    0.000
#
#         Condition         ORNs
# 1    male_fed_Air        Gr21a
# 7    male_fed_Air        Gr63a
# 11   male_fed_Air        Or10a
# 25   male_fed_Air         Or1a
# 59   male_fed_Air        Or33b
# 65   male_fed_Air  Or33b-Or85a
# 71   male_fed_Air        Or35a
# 79   male_fed_Air        Or42b
# 107  male_fed_Air        Or47a
# 119  male_fed_Air        Or49a
# 135  male_fed_Air        Or59b
# 139  male_fed_Air        Or59c
# 173  male_fed_Air        Or67c
# 187  male_fed_Air        Or71a
# 207  male_fed_Air        Or83c
# 226  male_fed_Air        Or85d
# 243  male_fed_Air        Or88a
# 263  male_fed_Air         Orco

# %%
allData_meanFixedFALSE_df[allData_meanFixedFALSE_df['ZI.Protein'].str.contains('Or42b')]
# Out:
#     Unnamed: 0                       ZI.Protein  ZI.MedianRatio  ZI.PepNum  \
# 78          79             Or42b_male_fed_NoAir           0.237          5
# 79          80               Or42b_male_fed_Air           0.154          5
# 80          81         Or42b_male_starved_NoAir           0.167          5
# 81          82           Or42b_male_starved_Air           0.048          5
# 82          83      Or42b-Or92a_male_fed_NoWind           0.254          3
# 83          84        Or42b-Or92a_male_fed_Wind           0.053          3
# 84          85  Or42b-Or92a_male_starved_NoWind           0.141          3
# 85          86    Or42b-Or92a_male_starved_Wind           0.120          3
#
#     ZI.PepNumRemoved  ZI.Probability  ZI.FLAG  ZI.PosteriorOdds  ZI.BFDR  \
# 78                 0           1.000      NaN            10.780    0.000
# 79                 0           1.000      NaN            10.620    0.000
# 80                 0           0.001      NaN            -6.504    0.709
# 81                 0           0.003      NaN            -5.688    0.680
# 82                 0           0.843      NaN             1.677    0.032
# 83                 0           0.000      NaN            -6.253    0.764
# 84                 0           0.022      NaN            -3.797    0.557
# 85                 0           0.088      NaN            -2.335    0.397
#
#               Condition         ORNs
# 78       male_fed_NoAir        Or42b
# 79         male_fed_Air        Or42b
# 80   male_starved_NoAir        Or42b
# 81     male_starved_Air        Or42b
# 82      male_fed_NoWind  Or42b-Or92a
# 83        male_fed_Wind  Or42b-Or92a
# 84  male_starved_NoWind  Or42b-Or92a
# 85    male_starved_Wind  Or42b-Or92a

# %% [markdown]
# ## Calculate delta-delta Z scores

# %%
Z_scores_df_dropna
# Out:
#            Di LightInt   ORNs      Sex_Satiety_Wind        Si        Zi  \
# 0    0.090131     14uW  Gr21a        male_fed_NoAir  0.427006  0.120628
# 1   -0.243048     42uW  Gr21a        male_fed_NoAir  0.346521 -0.364557
# 2   -0.134207     70uW  Gr21a        male_fed_NoAir  0.345914 -0.201485
# 3    0.044154     14uW  Gr21a          male_fed_Air  0.523822  0.052316
# 4   -0.131724     42uW  Gr21a          male_fed_Air  0.428363 -0.175975
# 5   -0.197315     70uW  Gr21a          male_fed_Air  0.499151 -0.240827
# 6    0.078018     14uW  Gr21a    male_starved_NoAir  0.432651  0.103633
# 7   -0.189169     42uW  Gr21a    male_starved_NoAir  0.292172 -0.308925
# 8   -0.192463     70uW  Gr21a    male_starved_NoAir  0.283009 -0.319079
# 9   -0.037381     14uW  Gr21a      male_starved_Air  0.464686 -0.047628
# 10  -0.103921     42uW  Gr21a      male_starved_Air  0.381695 -0.148063
# 11  -0.177794     70uW  Gr21a      male_starved_Air  0.349230 -0.265601
# 12  -0.018967     14uW  Gr63a    male_starved_NoAir  0.473301 -0.023903
# 13   0.105618     42uW  Gr63a    male_starved_NoAir  0.417341  0.143208
# 14   0.007042     70uW  Gr63a    male_starved_NoAir  0.437511  0.009294
# 15  -0.408698     14uW  Gr63a      male_starved_Air  0.553870 -0.467594
# 16  -0.246635     42uW  Gr63a      male_starved_Air  0.484545 -0.306485
# 17  -0.250337     70uW  Gr63a      male_starved_Air  0.494305 -0.307358
# 18  -0.025401     14uW  Gr63a        male_fed_NoAir  0.463212 -0.032424
# 19  -0.066340     42uW  Gr63a        male_fed_NoAir  0.413382 -0.090436
# 20  -0.008951     70uW  Gr63a        male_fed_NoAir  0.415281 -0.012170
# 21  -0.049420     14uW  Gr63a          male_fed_Air  0.551528 -0.056693
# 22  -0.287506     42uW  Gr63a          male_fed_Air  0.496788 -0.351921
# 23  -0.288192     70uW  Gr63a          male_fed_Air  0.427501 -0.385451
# 24  -0.652523     14uW  Gr66a    male_starved_NoAir  0.365965 -0.951007
# 25  -0.802015     42uW  Gr66a    male_starved_NoAir  0.273661 -1.350567
# 26  -0.858589     70uW  Gr66a    male_starved_NoAir  0.249410 -1.507397
# 27  -0.698350     14uW  Gr66a      male_starved_Air  0.409581 -0.956965
# 28  -0.804364     42uW  Gr66a      male_starved_Air  0.302400 -1.291996
# 29  -0.866331     70uW  Gr66a      male_starved_Air  0.287300 -1.426119
# ..        ...      ...    ...                   ...       ...       ...
# 842  0.074070     14uW   Or9a        male_fed_NoAir  0.455355  0.095509
# 843  0.035658     42uW   Or9a        male_fed_NoAir  0.500072  0.043472
# 844  0.165264     70uW   Or9a        male_fed_NoAir  0.414477  0.224956
# 845  0.146441     14uW   Or9a          male_fed_Air  0.603795  0.158491
# 846 -0.007014     42uW   Or9a          male_fed_Air  0.545002 -0.008107
# 847  0.154510     70uW   Or9a          male_fed_Air  0.559774  0.175590
# 848  0.048294     14uW   Orco    male_starved_NoAir  0.509191  0.058230
# 849  0.135630     42uW   Orco    male_starved_NoAir  0.491487  0.167102
# 850  0.182030     70uW   Orco    male_starved_NoAir  0.430401  0.242521
# 851  0.255465     14uW   Orco      male_starved_Air  0.604491  0.276279
# 852  0.426554     42uW   Orco      male_starved_Air  0.552758  0.488645
# 853  0.401259     70uW   Orco      male_starved_Air  0.488485  0.496204
# 854  0.052353     14uW   Orco        male_fed_NoAir  0.538653  0.060958
# 855  0.289947     42uW   Orco        male_fed_NoAir  0.521173  0.344622
# 856  0.272716     70uW   Orco        male_fed_NoAir  0.513120  0.327275
# 857  0.147811     14uW   Orco          male_fed_Air  0.612954  0.158404
# 858  0.463668     42uW   Orco          male_fed_Air  0.578495  0.515950
# 859  0.472507     70uW   Orco          male_fed_Air  0.506720  0.571424
# 860 -0.113971     14uW   Orco      female_fed_NoAir  0.487912 -0.141039
# 861 -0.050173     42uW   Orco      female_fed_NoAir  0.556962 -0.057201
# 862 -0.039523     70uW   Orco      female_fed_NoAir  0.473385 -0.049805
# 863  0.000403     14uW   Orco        female_fed_Air  0.578358  0.000448
# 864 -0.096886     42uW   Orco        female_fed_Air  0.557936 -0.110334
# 865  0.132802     70uW   Orco        female_fed_Air  0.522702  0.157558
# 866  0.064503     14uW   Orco  female_starved_NoAir  0.483199  0.080290
# 867  0.213645     42uW   Orco  female_starved_NoAir  0.428637  0.285312
# 868  0.360068     70uW   Orco  female_starved_NoAir  0.354644  0.533577
# 869 -0.122330     14uW   Orco    female_starved_Air  0.480809 -0.152725
# 870  0.200951     42uW   Orco    female_starved_Air  0.514582  0.240730
# 871  0.246195     70uW   Orco    female_starved_Air  0.470411  0.311409
#
#                            Tag
# 0         Gr21a_male_fed_NoAir
# 1         Gr21a_male_fed_NoAir
# 2         Gr21a_male_fed_NoAir
# 3           Gr21a_male_fed_Air
# 4           Gr21a_male_fed_Air
# 5           Gr21a_male_fed_Air
# 6     Gr21a_male_starved_NoAir
# 7     Gr21a_male_starved_NoAir
# 8     Gr21a_male_starved_NoAir
# 9       Gr21a_male_starved_Air
# 10      Gr21a_male_starved_Air
# 11      Gr21a_male_starved_Air
# 12    Gr63a_male_starved_NoAir
# 13    Gr63a_male_starved_NoAir
# 14    Gr63a_male_starved_NoAir
# 15      Gr63a_male_starved_Air
# 16      Gr63a_male_starved_Air
# 17      Gr63a_male_starved_Air
# 18        Gr63a_male_fed_NoAir
# 19        Gr63a_male_fed_NoAir
# 20        Gr63a_male_fed_NoAir
# 21          Gr63a_male_fed_Air
# 22          Gr63a_male_fed_Air
# 23          Gr63a_male_fed_Air
# 24    Gr66a_male_starved_NoAir
# 25    Gr66a_male_starved_NoAir
# 26    Gr66a_male_starved_NoAir
# 27      Gr66a_male_starved_Air
# 28      Gr66a_male_starved_Air
# 29      Gr66a_male_starved_Air
# ..                         ...
# 842        Or9a_male_fed_NoAir
# 843        Or9a_male_fed_NoAir
# 844        Or9a_male_fed_NoAir
# 845          Or9a_male_fed_Air
# 846          Or9a_male_fed_Air
# 847          Or9a_male_fed_Air
# 848    Orco_male_starved_NoAir
# 849    Orco_male_starved_NoAir
# 850    Orco_male_starved_NoAir
# 851      Orco_male_starved_Air
# 852      Orco_male_starved_Air
# 853      Orco_male_starved_Air
# 854        Orco_male_fed_NoAir
# 855        Orco_male_fed_NoAir
# 856        Orco_male_fed_NoAir
# 857          Orco_male_fed_Air
# 858          Orco_male_fed_Air
# 859          Orco_male_fed_Air
# 860      Orco_female_fed_NoAir
# 861      Orco_female_fed_NoAir
# 862      Orco_female_fed_NoAir
# 863        Orco_female_fed_Air
# 864        Orco_female_fed_Air
# 865        Orco_female_fed_Air
# 866  Orco_female_starved_NoAir
# 867  Orco_female_starved_NoAir
# 868  Orco_female_starved_NoAir
# 869    Orco_female_starved_Air
# 870    Orco_female_starved_Air
# 871    Orco_female_starved_Air
#
# [834 rows x 7 columns]
